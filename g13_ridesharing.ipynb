# %%
import pandas as pd
import sqlite3

# %%
df = pd.read_excel("data/g13_ridesharing.xlsx")
conn = sqlite3.connect("data/g13_ridesharing.db")

# %%
cars = df.loc[:, ['id_car', 'description', 'id_company', 'car_type']].copy()
cars = cars.drop_duplicates(subset='id_car', keep='first')
cars['id_car'] = cars['id_car'].astype(int)
cars['id_company'] = cars['id_company'].astype(int)
cars['car_type'] = cars['car_type'].astype(int)
cars = cars.rename(columns={'id_car': 'id'})

# %%
cars.to_sql("Car", conn, if_exists="append", index=False)
# Out:
# 1199

# %%
pd.read_sql("SELECT * FROM Car LIMIT 20", conn)
# Out:
#     id  description  id_company  car_type
# 0    1        trade         347         1
# 1    2        force          60         1
# 2    3      subject         307         1
# 3    4         most         373         1
# 4    5      serious          68         1
# 5    6         hand         156         1
# 6    7      current         413         1
# 7    8  traditional         415         1
# 8    9        after         429         1
# 9   10         full         461         1
# 10  11     indicate          68         1
# 11  12          yes         220         1
# 12  13         lose         329         1
# 13  14    interview         484         1
# 14  15    direction         301         1
# 15  16      machine         301         1
# 16  17      against          95         1
# 17  18     customer         436         1
# 18  19        heavy         424         1
# 19  20      company         165         1

# %%
companies = df.loc[:, ['id_company', 'name', 'begin_date']].copy()
companies = companies.drop_duplicates(subset='id_company', keep='first')
companies['id_company'] = companies['id_company'].astype(int)
companies = companies.rename(columns={'id_company': 'id'})

# %%
companies.to_sql("Company", conn, if_exists="append", index=False)
# Out:
# 500

# %%
pd.read_sql("SELECT * FROM Company LIMIT 20", conn)
# Out:
#     id                            name  begin_date
# 0    1                   Roberts-Hurst  25/12/2025
# 1    2       Brewer, Gregory and Kelly  15/05/2022
# 2    3       Pugh, Harrison and Martin  02/03/2023
# 3    4                   Roberts-Hicks  22/01/2025
# 4    5         Hahn, Allen and Lambert  07/10/2023
# 5    6                   Clark-Spencer  22/08/2022
# 6    7     Miller, Gutierrez and Stark  23/12/2022
# 7    8  Bradshaw, Strickland and Olson  08/05/2024
# 8    9                Marquez-Gonzalez  22/05/2023
# 9   10                 Nguyen-Williams  21/07/2024
# 10  11               Martinez-Thompson  03/05/2024
# 11  12                  Holloway-Smith  11/11/2021
# 12  13                   Robinson-Kemp  23/11/2024
# 13  14       Romero, Johnson and Lopez  18/01/2023
# 14  15              Williamson-Gilbert  12/02/2022
# 15  16                   Mayo and Sons  09/03/2022
# 16  17                   Norton-Watson  13/03/2021
# 17  18                     Escobar LLC  22/12/2024
# 18  19    Gutierrez, Johnson and Jones  29/03/2023
# 19  20                     Massey-Pace  18/02/2022

# %%
contracts = df.loc[:, ['id_contract', 'contract_start', 'contract_end', 'id_company', 'id_driver']].copy()
contracts = contracts.drop_duplicates(subset='id_contract', keep='first')
contracts['id_contract'] = contracts['id_contract'].astype(int)
contracts['id_company'] = contracts['id_company'].astype(int)
contracts['id_driver'] = contracts['id_driver'].astype(int)
contracts = contracts.rename(columns={'id_contract': 'id'})

# %%
contracts.to_sql("Contract", conn, if_exists="append", index=False)
# Out:
# 9907

# %%
pd.read_sql("SELECT * FROM Contract LIMIT 20", conn)
# Out:
#     id       contract_start         contract_end  id_company  id_driver
# 0    1  06/10/2024 15:47:00                 None         403        762
# 1    2  25/04/2024 15:05:00  21/08/2026 15:05:00         348        312
# 2    3  04/10/2024 08:18:00  21/05/2025 08:18:00         423        641
# 3    4  27/01/2025 12:25:00                 None         205        444
# 4    5  30/08/2024 20:07:00                 None          81        789
# 5    6  26/11/2021 12:23:00  03/11/2024 12:23:00          85        537
# 6    7  31/03/2025 07:07:00                 None         149        956
# 7    8  27/01/2025 20:37:00  31/08/2025 20:37:00         205        698
# 8    9  14/02/2022 13:21:00  21/11/2023 13:21:00          34        771
# 9   10  14/07/2024 08:00:00  29/11/2025 08:00:00         407        261
# 10  11  08/01/2023 11:28:00                 None          88        943
# 11  12  12/04/2022 07:11:00                 None         320        192
# 12  13  06/04/2022 12:18:00                 None         207        723
# 13  14  07/05/2025 20:31:00                 None         347        551
# 14  15  13/05/2024 08:56:00  21/11/2026 08:56:00         359        903
# 15  16  11/05/2023 17:22:00  07/05/2024 17:22:00         383        610
# 16  17  10/12/2021 17:36:00                 None         322        441
# 17  18  19/12/2024 10:37:00                 None         362        114
# 18  19  15/05/2021 10:58:00                 None         282        340
# 19  20  12/10/2023 08:47:00                 None         315        826

# %%
customers = df.loc[:, ['id_customer', 'name_customer', 'email', 'phone', 'date_of_birth']].copy()
customers = customers.drop_duplicates(subset='id_customer', keep='first')
customers['id_customer'] = customers['id_customer'].astype(int)
customers['phone'] = customers['phone'].astype(int)
customers = customers.rename(columns={'id_customer': 'id'})
customers = customers.rename(columns={'name_customer': 'name'})

# %%
customers.to_sql("Customer", conn, if_exists="append", index=False)
# Out:
# 40

# %%
pd.read_sql("SELECT * FROM Customer LIMIT 20", conn)
# Out:
#     id              name                          email      phone  \
# 0    1         Ana Costa         ana.costa896@gmail.com  900382935
# 1    2      Ana Ferreira    ana.ferreira244@outlook.com  900077394
# 2    3       Ana Pereira      ana.pereira86@outlook.com  900382454
# 3    4        Ana Santos      ana.santos181@outlook.com  900095407
# 4    5         Ana Silva         ana.silva192@gmail.com  900073015
# 5    6     Goncalo Costa     goncalo.costa154@gmail.com  900049867
# 6    7  Goncalo Ferreira  goncalo.ferreira385@gmail.com  900236832
# 7    8   Goncalo Pereira  goncalo.pereira109@icloud.com  900168951
# 8    9    Goncalo Santos    goncalo.santos239@gmail.com  900892644
# 9   10     Goncalo Silva    goncalo.silva465@icloud.com  900133976
# 10  11        Ines Costa       ines.costa852@icloud.com  900509648
# 11  12     Ines Ferreira     ines.ferreira114@gmail.com  900044296
# 12  13      Ines Pereira     ines.pereira158@icloud.com  900252235
# 13  14       Ines Santos      ines.santos161@icloud.com  900182383
# 14  15        Ines Silva        ines.silva102@gmail.com  900358102
# 15  16        Joao Costa         joao.costa16@gmail.com  900181252
# 16  17     Joao Ferreira     joao.ferreira201@gmail.com  900034900
# 17  18      Joao Pereira    joao.pereira271@outlook.com  900364993
# 18  19       Joao Santos       joao.santos10@icloud.com  900406029
# 19  20        Joao Silva       joao.silva196@icloud.com  900106759
#
#    date_of_birth
# 0     25/09/1988
# 1     13/01/1978
# 2     11/07/1971
# 3     02/12/1999
# 4     09/02/1977
# 5     20/06/1996
# 6     20/08/1991
# 7     02/07/1971
# 8     10/11/1979
# 9     21/10/1994
# 10    20/10/2010
# 11    13/05/1989
# 12    17/02/1974
# 13    31/10/1980
# 14    14/12/1990
# 15    21/10/1995
# 16    13/07/1993
# 17    06/09/1986
# 18    14/10/1980
# 19    25/01/1980

# %%
drivers = df.loc[:, ['id_driver', 'nickname', 'driver_type', 'ratings']].copy()
drivers = drivers.drop_duplicates(subset='id_driver', keep='first')
drivers['id_driver'] = drivers['id_driver'].astype(int)
drivers = drivers.rename(columns={'id_driver': 'id'})

# %%
drivers.to_sql("Driver", conn, if_exists="append", index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 drivers.to_sql("Driver", conn, if_exists="append", index=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:3109, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2911 """
#    2912 Write records stored in a DataFrame to a SQL database.
#    2913
#    (...)   3105 [(1,), (None,), (2,)]
#    3106 """  # noqa: E501
#    3107 from pandas.io import sql
# -> 3109 return sql.to_sql(
#    3110     self,
#    3111     name,
#    3112     con,
#    3113     schema=schema,
#    3114     if_exists=if_exists,
#    3115     index=index,
#    3116     index_label=index_label,
#    3117     chunksize=chunksize,
#    3118     dtype=dtype,
#    3119     method=method,
#    3120 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:844, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     839     raise NotImplementedError(
#     840         "'frame' argument should be either a Series or a DataFrame"
#     841     )
#     843 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 844     return pandas_sql.to_sql(
#     845         frame,
#     846         name,
#     847         if_exists=if_exists,
#     848         index=index,
#     849         index_label=index_label,
#     850         schema=schema,
#     851         chunksize=chunksize,
#     852         dtype=dtype,
#     853         method=method,
#     854         engine=engine,
#     855         **engine_kwargs,
#     856     )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:2841, in SQLiteDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2831 table = SQLiteTable(
#    2832     name,
#    2833     self,
#    (...)   2838     dtype=dtype,
#    2839 )
#    2840 table.create()
# -> 2841 return table.insert(chunksize, method)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:1121, in SQLTable.insert(self, chunksize, method)
#    1118     break
#    1120 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1121 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1122 # GH 46891
#    1123 if num_inserted is not None:
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:2537, in SQLiteTable._execute_insert(self, conn, keys, data_iter)
#    2535 def _execute_insert(self, conn, keys, data_iter) -> int:
#    2536     data_list = list(data_iter)
# -> 2537     conn.executemany(self.insert_statement(num_rows=1), data_list)
#    2538     return conn.rowcount
#
# OperationalError: table Driver has no column named ratings

# %%
pd.read_sql("SELECT * FROM Driver LIMIT 20", conn)

# %%
rides = df.loc[:, ['id_ride', 'id_company', 'id_driver', 'id_customer', 'id_car', 'origin', 'destination', 'ride_date']].copy()
rides = rides.drop_duplicates(subset='id_ride', keep='first')
rides['id_ride'] = rides['id_ride'].astype(int)
rides['id_company'] = rides['id_company'].astype(int)
rides['id_driver'] = rides['id_driver'].astype(int)
rides['id_customer'] = rides['id_customer'].astype(int)
rides['id_car'] = rides['id_car'].astype(int)
rides = rides.rename(columns={'id_ride': 'id'})

# %%
rides.to_sql("Ride", conn, if_exists="append", index=False)
# Out:
# 10827

# %%
pd.read_sql("SELECT * FROM Ride LIMIT 20", conn)
# Out:
#     id  id_company  id_driver  id_customer  id_car  \
# 0    1         403        762            1    1199
# 1    2         348        312            1    1198
# 2    3         423        641            1    1197
# 3    4         205        444            1     155
# 4    5          81        789            1    1196
# 5    6          85        537            1      87
# 6    7         149        956            1    1195
# 7    8         205        698            1     155
# 8    9          34        771            1     136
# 9   10         407        261            1    1194
# 10  11          88        943            1    1193
# 11  12         320        192            1    1192
# 12  13         207        723            1    1191
# 13  14         347        551            1       1
# 14  15         359        903            1      97
# 15  16         383        610            1     126
# 16  17         322        441            1    1190
# 17  18         362        114            1    1189
# 18  19         282        340            1    1188
# 19  20         315        826            1    1187
#
#                                    origin  \
# 0   R. Dr. Roberto Frias, Porto, Portugal
# 1           Rua Augusta, Lisbon, Portugal
# 2           Rua Augusta, Lisbon, Portugal
# 3                         Braga, Portugal
# 4                          Faro, Portugal
# 5                     Guimarães, Portugal
# 6                          Faro, Portugal
# 7   R. de Santa Catarina, Porto, Portugal
# 8                        Aveiro, Portugal
# 9                     Guimarães, Portugal
# 10                    Guimarães, Portugal
# 11    Praça do Comércio, Lisbon, Portugal
# 12    Praça do Comércio, Lisbon, Portugal
# 13                       Aveiro, Portugal
# 14  R. Dr. Roberto Frias, Porto, Portugal
# 15                      Coimbra, Portugal
# 16                       Aveiro, Portugal
# 17  Rua de Santo António, Braga, Portugal
# 18                    Guimarães, Portugal
# 19    Praça do Comércio, Lisbon, Portugal
#
#                                 destination   ride_date
# 0                       Vila Real, Portugal  14/11/2024
# 1     R. de Santa Catarina, Porto, Portugal  31/05/2024
# 2                       Guimarães, Portugal  24/11/2024
# 3                       Vila Real, Portugal  01/03/2025
# 4                       Vila Real, Portugal  22/11/2024
# 5   Rua de Fernandes Tomás, Porto, Portugal  02/05/2022
# 6                         Coimbra, Portugal  27/07/2025
# 7                       Vila Real, Portugal  07/04/2025
# 8   Rua de Fernandes Tomás, Porto, Portugal  04/01/2025
# 9     R. de Santa Catarina, Porto, Portugal  13/08/2024
# 10                         Aveiro, Portugal  18/10/2023
# 11                         Aveiro, Portugal  16/05/2022
# 12    R. Dr. Roberto Frias, Porto, Portugal  19/06/2022
# 13            Rua Augusta, Lisbon, Portugal  29/07/2025
# 14            Rua Augusta, Lisbon, Portugal  16/06/2024
# 15                         Aveiro, Portugal  20/06/2024
# 16    R. de Santa Catarina, Porto, Portugal  08/09/2025
# 17                          Porto, Portugal  24/03/2025
# 18         Av. da Boavista, Porto, Portugal  11/04/2025
# 19    Rua de Santo António, Braga, Portugal  02/12/2023

# %%
#testar codigo de novo; eliminar colunas da base de dados
cur = conn.cursor()
cur.execute("DELETE FROM Car;")
cur.execute("DELETE FROM Company;")
cur.execute("DELETE FROM Contract;")
cur.execute("DELETE FROM Customer;")

cur.execute("DELETE FROM Driver;")
cur.execute("DELETE FROM Ride;")
conn.commit()

# %%
conn.close()
